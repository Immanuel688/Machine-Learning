# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
param_grid={'n_estimators':[10,20,50,100,1000], 'loss': ['linear','square','exponential'],'random_state':[None,1]}
grid=GridSearchCV(AdaBoostRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Anaconda3run\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 20, 50, 100, 1000],
#                          'random_state': [None, 1]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'loss': 'linear', 'n_estimators': 20, 'random_state': None}

# %%
grid.best_score_
# Out:
# 0.8240262454966203

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time   param_loss  \
# 0        0.046863      0.009879         0.006249    7.653254e-03       linear
# 1        0.040614      0.012497         0.006249    7.653079e-03       linear
# 2        0.040616      0.015931         0.006248    7.652319e-03       linear
# 3        0.046864      0.017112         0.000000    0.000000e+00       linear
# 4        0.043742      0.018217         0.006249    7.652845e-03       linear
# 5        0.040614      0.007651         0.009372    7.652281e-03       linear
# 6        0.046867      0.017120         0.003124    6.248379e-03       linear
# 7        0.040612      0.012501         0.006251    7.656117e-03       linear
# 8        0.040611      0.007649         0.006249    7.652903e-03       linear
# 9        0.037493      0.007651         0.003125    6.249142e-03       linear
# 10       0.040613      0.007652         0.003127    6.253529e-03       square
# 11       0.037491      0.007653         0.006249    7.652962e-03       square
# 12       0.087480      0.007653         0.003125    6.249046e-03       square
# 13       0.074982      0.011690         0.006249    7.653838e-03       square
# 14       0.190581      0.037491         0.018745    6.247664e-03       square
# 15       0.162880      0.005978         0.015622    4.623108e-07       square
# 16       0.347031      0.015195         0.027910    2.924491e-03       square
# 17       0.336258      0.022519         0.025054    5.154339e-03       square
# 18       3.210958      0.129170         0.241843    3.096947e-02       square
# 19       3.118581      0.141169         0.240510    4.645234e-02       square
# 20       0.046844      0.017113         0.004321    6.107249e-03  exponential
# 21       0.034892      0.006071         0.006248    7.652728e-03  exponential
# 22       0.087479      0.021190         0.012497    1.169016e-02  exponential
# 23       0.099977      0.007652         0.003124    6.248665e-03  exponential
# 24       0.201920      0.027387         0.012196    6.125870e-03  exponential
# 25       0.198407      0.030523         0.012408    5.457358e-03  exponential
# 26       0.406110      0.014764         0.031975    6.133054e-03  exponential
# 27       0.420736      0.038586         0.026529    4.018602e-03  exponential
# 28       3.038850      0.118799         0.213741    8.722419e-03  exponential
# 29       2.918288      0.157259         0.211130    5.228241e-02  exponential
#
#    param_n_estimators param_random_state  \
# 0                  10               None
# 1                  10                  1
# 2                  20               None
# 3                  20                  1
# 4                  50               None
# 5                  50                  1
# 6                 100               None
# 7                 100                  1
# 8                1000               None
# 9                1000                  1
# 10                 10               None
# 11                 10                  1
# 12                 20               None
# 13                 20                  1
# 14                 50               None
# 15                 50                  1
# 16                100               None
# 17                100                  1
# 18               1000               None
# 19               1000                  1
# 20                 10               None
# 21                 10                  1
# 22                 20               None
# 23                 20                  1
# 24                 50               None
# 25                 50                  1
# 26                100               None
# 27                100                  1
# 28               1000               None
# 29               1000                  1
#
#                                                params  split0_test_score  \
# 0   {'loss': 'linear', 'n_estimators': 10, 'random...           0.833531
# 1   {'loss': 'linear', 'n_estimators': 10, 'random...           0.841690
# 2   {'loss': 'linear', 'n_estimators': 20, 'random...           0.838241
# 3   {'loss': 'linear', 'n_estimators': 20, 'random...           0.841690
# 4   {'loss': 'linear', 'n_estimators': 50, 'random...           0.840993
# 5   {'loss': 'linear', 'n_estimators': 50, 'random...           0.841690
# 6   {'loss': 'linear', 'n_estimators': 100, 'rando...           0.838516
# 7   {'loss': 'linear', 'n_estimators': 100, 'rando...           0.841690
# 8   {'loss': 'linear', 'n_estimators': 1000, 'rand...           0.812155
# 9   {'loss': 'linear', 'n_estimators': 1000, 'rand...           0.841690
# 10  {'loss': 'square', 'n_estimators': 10, 'random...           0.708361
# 11  {'loss': 'square', 'n_estimators': 10, 'random...           0.681743
# 12  {'loss': 'square', 'n_estimators': 20, 'random...           0.610235
# 13  {'loss': 'square', 'n_estimators': 20, 'random...           0.618416
# 14  {'loss': 'square', 'n_estimators': 50, 'random...           0.533409
# 15  {'loss': 'square', 'n_estimators': 50, 'random...           0.551106
# 16  {'loss': 'square', 'n_estimators': 100, 'rando...           0.497754
# 17  {'loss': 'square', 'n_estimators': 100, 'rando...           0.505293
# 18  {'loss': 'square', 'n_estimators': 1000, 'rand...           0.485239
# 19  {'loss': 'square', 'n_estimators': 1000, 'rand...           0.482839
# 20  {'loss': 'exponential', 'n_estimators': 10, 'r...           0.828995
# 21  {'loss': 'exponential', 'n_estimators': 10, 'r...           0.825368
# 22  {'loss': 'exponential', 'n_estimators': 20, 'r...           0.731580
# 23  {'loss': 'exponential', 'n_estimators': 20, 'r...           0.733865
# 24  {'loss': 'exponential', 'n_estimators': 50, 'r...           0.620377
# 25  {'loss': 'exponential', 'n_estimators': 50, 'r...           0.612497
# 26  {'loss': 'exponential', 'n_estimators': 100, '...           0.554412
# 27  {'loss': 'exponential', 'n_estimators': 100, '...           0.560825
# 28  {'loss': 'exponential', 'n_estimators': 1000, ...           0.514908
# 29  {'loss': 'exponential', 'n_estimators': 1000, ...           0.510024
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.794138           0.843683           0.820642
# 1            0.774483           0.838822           0.823239
# 2            0.780828           0.839418           0.819159
# 3            0.774483           0.838822           0.823239
# 4            0.775917           0.841384           0.815978
# 5            0.774483           0.838822           0.823239
# 6            0.769003           0.842396           0.800811
# 7            0.774483           0.838822           0.823239
# 8            0.762048           0.847951           0.822977
# 9            0.774483           0.838822           0.823239
# 10           0.613483           0.663826           0.679648
# 11           0.624303           0.669249           0.707794
# 12           0.487286           0.559244           0.580316
# 13           0.511685           0.532215           0.576893
# 14           0.430634           0.458969           0.506081
# 15           0.423937           0.457303           0.485613
# 16           0.370601           0.424937           0.461999
# 17           0.384741           0.413145           0.453354
# 18           0.361348           0.384321           0.431773
# 19           0.357734           0.386361           0.423070
# 20           0.755689           0.811837           0.794799
# 21           0.742600           0.835027           0.781803
# 22           0.718262           0.744481           0.729698
# 23           0.681083           0.728111           0.718170
# 24           0.515108           0.587673           0.621931
# 25           0.535746           0.572061           0.596468
# 26           0.437001           0.470962           0.519359
# 27           0.430651           0.488832           0.509847
# 28           0.330787           0.413911           0.419192
# 29           0.326661           0.409650           0.418256
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.824268         0.823252        0.016605                2
# 1            0.823106         0.820268        0.024151                3
# 2            0.842485         0.824026        0.023106                1
# 3            0.823106         0.820268        0.024151                3
# 4            0.816499         0.818154        0.023886                8
# 5            0.823106         0.820268        0.024151                3
# 6            0.816058         0.813357        0.026863               10
# 7            0.823106         0.820268        0.024151                3
# 8            0.833343         0.815695        0.029310                9
# 9            0.823106         0.820268        0.024151                3
# 10           0.716519         0.676368        0.036765               15
# 11           0.692482         0.675114        0.028389               16
# 12           0.569319         0.561280        0.040750               19
# 13           0.528612         0.553564        0.038942               20
# 14           0.491895         0.484197        0.035960               23
# 15           0.442035         0.471999        0.044423               24
# 16           0.460646         0.443188        0.042984               25
# 17           0.450307         0.441368        0.040775               26
# 18           0.433622         0.419260        0.043106               29
# 19           0.432492         0.416499        0.042571               30
# 20           0.813767         0.801017        0.025123               11
# 21           0.811469         0.799253        0.033541               12
# 22           0.752976         0.735399        0.012101               13
# 23           0.738926         0.720031        0.020660               14
# 24           0.593119         0.587642        0.038829               17
# 25           0.574327         0.578220        0.025942               18
# 26           0.527367         0.501820        0.042142               21
# 27           0.517063         0.501444        0.042453               22
# 28           0.455560         0.426871        0.060054               27
# 29           0.454625         0.423843        0.060086               28

# %%
result= grid.predict([[32,43,2,0,1]])
# Out:
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([44830.51943514])
