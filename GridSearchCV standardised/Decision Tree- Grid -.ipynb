# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= { 'criterion':['squared_error','friedman_mse','absolute_error',"poisson"], 'splitter':['best','random'], 'max_features':[None,'sqrt','log2']}
grid= GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1,cv=10)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print("The best parameter are {}:".format(grid.best_params_))
# Out:
# The best parameter are {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}:

# %%
re= grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011650      0.010431         0.002957        0.004362
# 1        0.004686      0.007158         0.000000        0.000000
# 2        0.005485      0.007036         0.000200        0.000599
# 3        0.004321      0.006107         0.001557        0.003692
# 4        0.000000      0.000000         0.003125        0.006249
# 5        0.003126      0.006252         0.000000        0.000000
# 6        0.001562      0.004687         0.003124        0.006249
# 7        0.001565      0.004695         0.000000        0.000000
# 8        0.004686      0.007158         0.001562        0.004687
# 9        0.001560      0.004681         0.003123        0.006246
# 10       0.009373      0.007653         0.000000        0.000000
# 11       0.001562      0.004686         0.001562        0.004686
# 12       0.053113      0.010364         0.000000        0.000000
# ...

# %%
result= grid.predict([[32,43,2,0,1]])

# %%
result
# Out:
# array([63770.42801])

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
grid.best_score_
# Out:
# 0.7188257927782555
