# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={ 'criterion': [ 'squared_error','friedman_mse','absolute_error','poisson'], 'n_estimators': [50,500,1000], 'max_features':[None,'sqrt','log2']}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 500, 1000]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 500}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.477813      0.021199         0.009373        0.007653
# 1        4.627187      0.077136         0.103656        0.009166
# 2        9.528851      0.183649         0.211527        0.039180
# 3        0.351855      0.026740         0.013166        0.002554
# 4        3.102933      0.074345         0.105481        0.039630
# 5        6.576527      0.246379         0.192677        0.012386
# 6        0.303784      0.009129         0.011172        0.000977
# 7        3.036578      0.027987         0.092540        0.010473
# 8        6.367255      0.050957         0.193702        0.012496
# 9        0.503007      0.034790         0.006248        0.007652
# 10       4.727010      0.050957         0.093729        0.009880
# 11       9.397794      0.094040         0.184330        0.011688
# 12       0.340546      0.045703         0.012495        0.006247
# 13       3.242989      0.061382         0.099978        0.015929
# 14       6.443936      0.044898         0.189833        0.010960
# 15       0.315550      0.018217         0.012498        0.006249
# 16       3.301035      0.062211         0.109347        0.009878
# 17       6.447005      0.169715         0.184333        0.011688
# 18       1.430914      0.032167         0.009373        0.007653
# 19      13.980083      0.196794         0.083168        0.006477
# 20      30.546549      1.024118         0.177897        0.009550
# 21       0.819870      0.032780         0.015621        0.009880
# 22       8.418393      0.115401         0.091166        0.016465
# 23      16.786404      0.109883         0.183649        0.015644
# 24       0.843552      0.035622         0.009373        0.007653
# 25       8.347766      0.178903         0.087480        0.012497
# 26      16.827822      0.259711         0.205436        0.030105
# 27       0.528170      0.032498         0.010197        0.008655
# 28       5.097848      0.100358         0.092044        0.012123
# 29      10.159942      0.102002         0.193704        0.007653
# 30       0.371787      0.018217         0.006249        0.007653
# 31       3.533545      0.075502         0.093728        0.017112
# 32       7.032566      0.054242         0.192163        0.015310
# 33       0.343851      0.009593         0.015623        0.009879
# 34       3.530421      0.055889         0.103101        0.015931
# 35       7.104661      0.171078         0.193701        0.027234
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 50
# 1    squared_error               None                500
# 2    squared_error               None               1000
# 3    squared_error               sqrt                 50
# 4    squared_error               sqrt                500
# 5    squared_error               sqrt               1000
# 6    squared_error               log2                 50
# 7    squared_error               log2                500
# 8    squared_error               log2               1000
# 9     friedman_mse               None                 50
# 10    friedman_mse               None                500
# 11    friedman_mse               None               1000
# 12    friedman_mse               sqrt                 50
# 13    friedman_mse               sqrt                500
# 14    friedman_mse               sqrt               1000
# 15    friedman_mse               log2                 50
# 16    friedman_mse               log2                500
# 17    friedman_mse               log2               1000
# 18  absolute_error               None                 50
# 19  absolute_error               None                500
# 20  absolute_error               None               1000
# 21  absolute_error               sqrt                 50
# 22  absolute_error               sqrt                500
# 23  absolute_error               sqrt               1000
# 24  absolute_error               log2                 50
# 25  absolute_error               log2                500
# 26  absolute_error               log2               1000
# 27         poisson               None                 50
# 28         poisson               None                500
# 29         poisson               None               1000
# 30         poisson               sqrt                 50
# 31         poisson               sqrt                500
# 32         poisson               sqrt               1000
# 33         poisson               log2                 50
# 34         poisson               log2                500
# 35         poisson               log2               1000
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.847117
# 1   {'criterion': 'squared_error', 'max_features':...           0.848783
# 2   {'criterion': 'squared_error', 'max_features':...           0.849299
# 3   {'criterion': 'squared_error', 'max_features':...           0.858827
# 4   {'criterion': 'squared_error', 'max_features':...           0.860077
# 5   {'criterion': 'squared_error', 'max_features':...           0.861036
# 6   {'criterion': 'squared_error', 'max_features':...           0.862008
# 7   {'criterion': 'squared_error', 'max_features':...           0.859887
# 8   {'criterion': 'squared_error', 'max_features':...           0.860076
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.846413
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.849907
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.849278
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.850597
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.858799
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.859231
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.857549
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.859152
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.860644
# 18  {'criterion': 'absolute_error', 'max_features'...           0.842464
# 19  {'criterion': 'absolute_error', 'max_features'...           0.840620
# 20  {'criterion': 'absolute_error', 'max_features'...           0.840673
# 21  {'criterion': 'absolute_error', 'max_features'...           0.853205
# 22  {'criterion': 'absolute_error', 'max_features'...           0.859591
# 23  {'criterion': 'absolute_error', 'max_features'...           0.860384
# 24  {'criterion': 'absolute_error', 'max_features'...           0.859490
# 25  {'criterion': 'absolute_error', 'max_features'...           0.858115
# 26  {'criterion': 'absolute_error', 'max_features'...           0.859027
# 27  {'criterion': 'poisson', 'max_features': None,...           0.846254
# 28  {'criterion': 'poisson', 'max_features': None,...           0.851764
# 29  {'criterion': 'poisson', 'max_features': None,...           0.851149
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856225
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860394
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.861378
# 33  {'criterion': 'poisson', 'max_features': 'log2...           0.858316
# 34  {'criterion': 'poisson', 'max_features': 'log2...           0.859888
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.860582
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0