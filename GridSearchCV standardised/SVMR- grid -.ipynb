# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset['charges']
dependent
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','linear','sigmoid'], 'C':[10,100,5000,10000,20000,40000], 'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1, cv=10)
grid.fit(independent,dependent)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# GridSearchCV(cv=10, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 5000, 10000, 20000, 40000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'linear', 'sigmoid']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 40000, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
re=grid.cv_results_

# %%
table= pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.132363      0.012716         0.031243        0.000002      10
# 1        0.118723      0.007653         0.006249        0.007653      10
# 2        0.146374      0.008019         0.016754        0.011070      10
# 3        0.133100      0.010600         0.031241        0.000005      10
# 4        0.114388      0.010952         0.012118        0.006162      10
# 5        0.151793      0.010828         0.014797        0.005960      10
# 6        0.140693      0.009169         0.029585        0.003665     100
# 7        0.120285      0.007157         0.006248        0.007652     100
# 8        0.154650      0.014737         0.009373        0.007653     100
# 9        0.132779      0.007811         0.034369        0.006250     100
# 10       0.126532      0.008414         0.004686        0.007159     100
# 11       0.154651      0.012976         0.010935        0.007159     100
# 12       0.237443      0.027770         0.031242        0.009880    5000
# 13       0.285869      0.022146         0.003124        0.006249    5000
# 14       0.165585      0.012497         0.017184        0.008413    5000
# 15       0.235881      0.021476         0.034369        0.006247    5000
# 16       0.284308      0.026876         0.001562        0.004687    5000
# 17       0.160900      0.012203         0.014059        0.008412    5000
# 18       0.334297      0.047996         0.031242        0.006985   10000
# 19       0.410016      0.041499         0.011746        0.006279   10000
# 20       0.167545      0.014804         0.011465        0.005919   10000
# 21       0.366196      0.041809         0.035320        0.008050   10000
# 22       0.415528      0.064861         0.009372        0.007652   10000
# 23       0.165585      0.012496         0.014061        0.004687   10000
# 24       0.620166      0.152106         0.034367        0.006248   20000
# 25       0.649846      0.047996         0.007813        0.007813   20000
# 26       0.165582      0.014318         0.010935        0.012201   20000
# 27       0.621730      0.147171         0.031241        0.009880   20000
# 28       0.643597      0.072198         0.007811        0.007811   20000
# 29       0.167147      0.017184         0.017184        0.012976   20000
# 30       1.165349      0.184594         0.031243        0.006986   40000
# 31       1.084120      0.087869         0.007811        0.007811   40000
# 32       0.171836      0.009880         0.012496        0.009372   40000
# 33       1.223150      0.267763         0.029681        0.008412   40000
# 34       1.070061      0.119431         0.009372        0.010362   40000
# 35       0.167148      0.015700         0.009373        0.007653   40000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto       linear
# 2         auto      sigmoid
# 3        scale          rbf
# 4        scale       linear
# 5        scale      sigmoid
# 6         auto          rbf
# 7         auto       linear
# 8         auto      sigmoid
# 9        scale          rbf
# 10       scale       linear
# 11       scale      sigmoid
# 12        auto          rbf
# 13        auto       linear
# 14        auto      sigmoid
# 15       scale          rbf
# 16       scale       linear
# 17       scale      sigmoid
# 18        auto          rbf
# 19        auto       linear
# 20        auto      sigmoid
# 21       scale          rbf
# 22       scale       linear
# 23       scale      sigmoid
# 24        auto          rbf
# 25        auto       linear
# 26        auto      sigmoid
# 27       scale          rbf
# 28       scale       linear
# 29       scale      sigmoid
# 30        auto          rbf
# 31        auto       linear
# 32        auto      sigmoid
# 33       scale          rbf
# 34       scale       linear
# 35       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.057278
# 1      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.517678
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.032458
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.057368
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.517678
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.032816
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.410519
# 7     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.652877
# 8    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.545833
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.410034
# 10   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.652877
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.545666
# 12      {'C': 5000, 'gamma': 'auto', 'kernel': 'rbf'}           0.889448
# 13   {'C': 5000, 'gamma': 'auto', 'kernel': 'linear'}           0.707430
# 14  {'C': 5000, 'gamma': 'auto', 'kernel': 'sigmoid'}         -13.080760
# 15     {'C': 5000, 'gamma': 'scale', 'kernel': 'rbf'}           0.889437
# 16  {'C': 5000, 'gamma': 'scale', 'kernel': 'linear'}           0.707430
# 17  {'C': 5000, 'gamma': 'scale', 'kernel': 'sigmo...         -13.739802
# 18     {'C': 10000, 'gamma': 'auto', 'kernel': 'rbf'}           0.886989
# 19  {'C': 10000, 'gamma': 'auto', 'kernel': 'linear'}           0.707426
# 20  {'C': 10000, 'gamma': 'auto', 'kernel': 'sigmo...         -60.945037
# 21    {'C': 10000, 'gamma': 'scale', 'kernel': 'rbf'}           0.886992
# 22  {'C': 10000, 'gamma': 'scale', 'kernel': 'line...           0.707426
# 23  {'C': 10000, 'gamma': 'scale', 'kernel': 'sigm...         -52.179377
# 24     {'C': 20000, 'gamma': 'auto', 'kernel': 'rbf'}           0.885945
# 25  {'C': 20000, 'gamma': 'auto', 'kernel': 'linear'}           0.707348
# 26  {'C': 20000, 'gamma': 'auto', 'kernel': 'sigmo...        -269.841925
# 27    {'C': 20000, 'gamma': 'scale', 'kernel': 'rbf'}           0.885923
# 28  {'C': 20000, 'gamma': 'scale', 'kernel': 'line...           0.707348
# 29  {'C': 20000, 'gamma': 'scale', 'kernel': 'sigm...        -269.038179
# 30     {'C': 40000, 'gamma': 'auto', 'kernel': 'rbf'}           0.883678
# 31  {'C': 40000, 'gamma': 'auto', 'kernel': 'linear'}           0.707347
# 32  {'C': 40000, 'gamma': 'auto', 'kernel': 'sigmo...        -930.429714
# 33    {'C': 40000, 'gamma': 'scale', 'kernel': 'rbf'}           0.883702
# 34  {'C': 40000, 'gamma': 'scale', 'kernel': 'line...           0.707347
# 35  {'C': 40000, 'gamma': 'scale', 'kernel': 'sigm...       -1045.590854
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 26        -279.524879        -235.409292        -274.531128
# 27           0.915480           0.861883           0.764544
# 28           0.701649           0.728866           0.526302
# 29        -286.788114        -235.478252        -277.263825
# 30           0.917115           0.865333           0.765349
# 31           0.701650           0.728870           0.526298
# 32       -1187.505078        -775.471788        -861.501621
# 33           0.917102           0.865335           0.765305
# 34           0.701650           0.728870           0.526298
# 35       -1074.691778        -776.322146        -889.780474
#
#     split8_test_score  split9_test_score  mean_test_score  std_test_score  \
# 0           -0.048232          -0.033999        -0.033850        0.033040
# 1            0.437187           0.497732         0.493525        0.041022
# 2            0.015959           0.050929         0.052732        0.037071
# 3           -0.048207          -0.034166        -0.033850        0.033055
# 4            0.437187           0.497732         0.493525        0.041022
# 5            0.015847           0.051563         0.052743        0.037005
# 6            0.354013           0.383919         0.383473        0.039505
# 7            0.591665           0.639032         0.633189        0.039361
# 8            0.461968           0.517069         0.510088        0.041139
# 9            0.354162           0.383032         0.383465        0.039529
# 10           0.591665           0.639032         0.633189        0.039361
# 11           0.462070           0.518520         0.510202        0.040746
# 12           0.834840           0.825601         0.832387        0.049002
# 13           0.685527           0.691819         0.662893        0.070392
# 14         -12.003251         -10.586197       -13.634301        1.925029
# 15           0.834852           0.825487         0.832369        0.049008
# 16           0.685527           0.691819         0.662893        0.070392
# 17         -11.930603          -9.808076       -13.983795        2.763566
# 18           0.836725           0.824918         0.833025        0.048801
# 19           0.685524           0.691821         0.662795        0.070314
# 20         -62.894521         -65.956944       -62.362392        8.736864
# 21           0.836719           0.824919         0.833019        0.048795
# 22           0.685524           0.691821         0.662795        0.070314
# 23         -63.825822         -65.653073       -61.866095        9.268662
# 24           0.837717           0.831808         0.835443        0.048570
# 25           0.685524           0.691821         0.662773        0.070293
# 26        -238.992507        -229.745389      -257.512325       38.993600
# 27           0.837726           0.831887         0.835447        0.048561
# 28           0.685524           0.691821         0.662773        0.070293
# 29        -292.090194        -234.650341      -254.007792       34.563587
# 30           0.834123           0.833576         0.835749        0.049064
# 31           0.685525           0.691825         0.662746        0.070297
# 32       -1163.583291        -883.398369      -997.865791      213.002699
# 33           0.834168           0.833604         0.835756        0.049068
# 34           0.685525           0.691825         0.662746        0.070297
# 35        -948.874293       -1007.983629     -1006.212836      218.667250
#
#     rank_test_score
# 0                27
# 1                21
# 2                26
# 3                28
# 4                21
# 5                25
# 6                23
# 7                17
# 8                20
# 9                24
# 10               17
# 11               19
# 12                7
# 13                9
# 14               29
# 15                8
# 16                9
# 17               30
# 18                5
# 19               11
# 20               32
# 21                6
# 22               11
# 23               31
# 24                4
# 25               13
# 26               34
# 27                3
# 28               13
# 29               33
# 30                2
# 31               15
# 32               35
# 33                1
# 34               15
# 35               36
#
# [36 rows x 21 columns]

# %%
grid.best_score_
# Out:
# 0.8357558629869754
