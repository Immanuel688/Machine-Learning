# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
param_grid={'n_estimators':[10,20,50], 'loss': ['linear','square','exponential'],'random_state':[None,1]}
grid=GridSearchCV(AdaBoostRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Anaconda3run\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 20, 50],
#                          'random_state': [None, 1]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'loss': 'linear', 'n_estimators': 10, 'random_state': None}

# %%
grid.best_score_
# Out:
# 0.8234666296235925

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time   param_loss  \
# 0        0.052549      0.025111         0.006621        0.007381       linear
# 1        0.035700      0.009674         0.006254        0.007660       linear
# 2        0.043737      0.011696         0.006247        0.007652       linear
# 3        0.034367      0.011690         0.006249        0.007653       linear
# 4        0.043317      0.011355         0.009840        0.004721       linear
# 5        0.036250      0.013326         0.009373        0.007653       linear
# 6        0.037494      0.007657         0.003124        0.006249       square
# 7        0.040615      0.012497         0.006252        0.007657       square
# 8        0.081228      0.011696         0.000000        0.000000       square
# 9        0.074982      0.006248         0.006249        0.007653       square
# 10       0.181945      0.021674         0.015448        0.000590       square
# 11       0.180907      0.009101         0.013043        0.006597       square
# 12       0.053363      0.015912         0.009042        0.005980  exponential
# 13       0.050329      0.011733         0.006155        0.001007  exponential
# 14       0.083636      0.001841         0.010014        0.004249  exponential
# 15       0.091607      0.010423         0.005427        0.006539  exponential
# 16       0.196318      0.006121         0.019002        0.007703  exponential
# 17       0.231657      0.015342         0.015501        0.000782  exponential
#
#    param_n_estimators param_random_state  \
# 0                  10               None
# 1                  10                  1
# 2                  20               None
# 3                  20                  1
# 4                  50               None
# 5                  50                  1
# 6                  10               None
# 7                  10                  1
# 8                  20               None
# 9                  20                  1
# 10                 50               None
# 11                 50                  1
# 12                 10               None
# 13                 10                  1
# 14                 20               None
# 15                 20                  1
# 16                 50               None
# 17                 50                  1
#
#                                                params  split0_test_score  \
# 0   {'loss': 'linear', 'n_estimators': 10, 'random...           0.849630
# 1   {'loss': 'linear', 'n_estimators': 10, 'random...           0.841690
# 2   {'loss': 'linear', 'n_estimators': 20, 'random...           0.844251
# 3   {'loss': 'linear', 'n_estimators': 20, 'random...           0.841690
# 4   {'loss': 'linear', 'n_estimators': 50, 'random...           0.842288
# 5   {'loss': 'linear', 'n_estimators': 50, 'random...           0.841690
# 6   {'loss': 'square', 'n_estimators': 10, 'random...           0.684713
# 7   {'loss': 'square', 'n_estimators': 10, 'random...           0.681743
# 8   {'loss': 'square', 'n_estimators': 20, 'random...           0.605475
# 9   {'loss': 'square', 'n_estimators': 20, 'random...           0.618416
# 10  {'loss': 'square', 'n_estimators': 50, 'random...           0.554064
# 11  {'loss': 'square', 'n_estimators': 50, 'random...           0.551106
# 12  {'loss': 'exponential', 'n_estimators': 10, 'r...           0.805184
# 13  {'loss': 'exponential', 'n_estimators': 10, 'r...           0.825368
# 14  {'loss': 'exponential', 'n_estimators': 20, 'r...           0.732970
# 15  {'loss': 'exponential', 'n_estimators': 20, 'r...           0.733865
# 16  {'loss': 'exponential', 'n_estimators': 50, 'r...           0.621107
# 17  {'loss': 'exponential', 'n_estimators': 50, 'r...           0.612497
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.770483           0.843592           0.813389
# 1            0.774483           0.838822           0.823239
# 2            0.774153           0.833022           0.805170
# 3            0.774483           0.838822           0.823239
# 4            0.783508           0.844577           0.811571
# 5            0.774483           0.838822           0.823239
# 6            0.610536           0.625505           0.681633
# 7            0.624303           0.669249           0.707794
# 8            0.528631           0.564859           0.632375
# 9            0.511685           0.532215           0.576893
# 10           0.423296           0.491105           0.495750
# 11           0.423937           0.457303           0.485613
# 12           0.757081           0.800967           0.791708
# 13           0.742600           0.835027           0.781803
# 14           0.695901           0.732557           0.721282
# 15           0.681083           0.728111           0.718170
# 16           0.536321           0.596475           0.611450
# 17           0.535746           0.572061           0.596468
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.840240         0.823467        0.029257                1
# 1            0.823106         0.820268        0.024151                3
# 2            0.841501         0.819619        0.026613                6
# 3            0.823106         0.820268        0.024151                3
# 4            0.830535         0.822496        0.022730                2
# 5            0.823106         0.820268        0.024151                3
# 6            0.698746         0.660227        0.035260               12
# 7            0.692482         0.675114        0.028389               11
# 8            0.570389         0.580346        0.035642               14
# 9            0.528612         0.553564        0.038942               16
# 10           0.467539         0.486351        0.042487               17
# 11           0.442035         0.471999        0.044423               18
# 12           0.811498         0.793288        0.019212                8
# 13           0.811469         0.799253        0.033541                7
# 14           0.735515         0.723645        0.014714                9
# 15           0.738926         0.720031        0.020660               10
# 16           0.584270         0.589925        0.029610               13
# 17           0.574327         0.578220        0.025942               15

# %%
result= grid.predict([[32,43,2,0,1]])
# Out:
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([43498.96087427])
