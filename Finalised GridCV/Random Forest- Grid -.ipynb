# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={ 'criterion': [ 'squared_error','friedman_mse','absolute_error','poisson'], 'n_estimators': [50,100], 'max_features':[None,'sqrt','log2']}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.509551      0.016248         0.016951    2.378890e-03
# 1        1.015010      0.044340         0.029598    7.253482e-03
# 2        0.361631      0.023446         0.016279    1.055914e-02
# 3        0.634165      0.032072         0.024994    7.653488e-03
# 4        0.328048      0.022091         0.009373    7.652709e-03
# 5        0.677618      0.028357         0.021870    7.652903e-03
# 6        0.466193      0.006717         0.012497    6.248593e-03
# 7        0.937281      0.034226         0.024993    7.651502e-03
# 8        0.312428      0.009878         0.012496    6.247974e-03
# 9        0.643599      0.038772         0.021872    7.655105e-03
# 10       0.331170      0.018219         0.006249    7.653721e-03
# 11       0.621727      0.026876         0.021870    7.652806e-03
# 12       1.412167      0.012497         0.012497    6.248570e-03
# ...

# %%
result= grid.predict([[32,43,2,0,1]])
# Out:
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([43256.127378])

# %%
grid.best_score_
# Out:
# 0.8351301207793584

# %%
age=int(input("Enter age:"))
bmi=float(input("Enter BMI:"))
Children=int(input("Enter no: of children:"))
sex_Male=int(input("Enter Sex Male 0 or 1:"))
smoker_yes=int(input("Enter smoker yes 0 or 1:"))
# Out:
# Enter age:32
# Enter BMI:43
# Enter no: of children:2
# Enter Sex Male 0 or 1:0
# Enter smoker yes 0 or 1:1

# %%
result_1= grid.predict([[age,bmi,Children,sex_Male,smoker_yes]])
# Out:
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result_1
# Out:
# array([43256.127378])
