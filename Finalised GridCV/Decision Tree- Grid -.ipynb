# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= { 'criterion':['squared_error','friedman_mse','absolute_error',"poisson"], 'splitter':['best','random'], 'max_features':[None,'sqrt','log2']}
grid= GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print("The best parameter are {}:".format(grid.best_params_))
# Out:
# The best parameter are {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}:

# %%
re= grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.021870  7.652884e-03         0.006248        0.007653
# 1        0.015620  9.880837e-03         0.003126        0.006251
# 2        0.015621  1.406468e-06         0.003124        0.006248
# 3        0.015622  2.336015e-07         0.000000        0.000000
# 4        0.009373  7.652787e-03         0.006248        0.007653
# 5        0.009373  7.652826e-03         0.003124        0.006249
# 6        0.015623  3.009745e-06         0.000000        0.000000
# 7        0.009375  7.654268e-03         0.003123        0.006246
# 8        0.009372  7.651853e-03         0.009373        0.007653
# 9        0.006248  7.652787e-03         0.012506        0.006253
# 10       0.006249  7.653651e-03         0.009372        0.007652
# 11       0.006257  7.662904e-03         0.003116        0.006232
# 12       0.046855  1.728757e-05         0.006248        0.007653
# 13       0.034367  6.248093e-03         0.003124        0.006248
# 14       0.028118  6.248811e-03         0.006248        0.007653
# 15       0.018745  6.244136e-03         0.009373        0.007653
# 16       0.031243  2.420154e-06         0.003124        0.006248
# 17       0.024995  7.652224e-03         0.000000        0.000000
# 18       0.015620  1.527368e-06         0.009373        0.007653
# 19       0.012498  6.249000e-03         0.000000        0.000000
# 20       0.009372  7.652592e-03         0.006249        0.007653
# 21       0.006249  7.653079e-03         0.009372        0.007653
# 22       0.009373  7.652748e-03         0.006249        0.007653
# 23       0.009372  7.652008e-03         0.006248        0.007652
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.731053
# 1   {'criterion': 'squared_error', 'max_features':...           0.722544
# 2   {'criterion': 'squared_error', 'max_features':...           0.740669
# 3   {'criterion': 'squared_error', 'max_features':...           0.702821
# 4   {'criterion': 'squared_error', 'max_features':...           0.769292
# 5   {'criterion': 'squared_error', 'max_features':...           0.693809
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.725745
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.710621
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.752540
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.649206
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.614970
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.671577
# 12  {'criterion': 'absolute_error', 'max_features'...           0.718129
# 13  {'criterion': 'absolute_error', 'max_features'...           0.689142
# 14  {'criterion': 'absolute_error', 'max_features'...           0.586929
# 15  {'criterion': 'absolute_error', 'max_features'...           0.726331
# 16  {'criterion': 'absolute_error', 'max_features'...           0.738477
# 17  {'criterion': 'absolute_error', 'max_features'...           0.751684
# 18  {'criterion': 'poisson', 'max_features': None,...           0.746782
# 19  {'criterion': 'poisson', 'max_features': None,...           0.704762
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.662011
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.651623
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.720494
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.656298
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.634526           0.732598           0.729490
# 1            0.477926           0.733638           0.721585
# 2            0.598694           0.739740           0.745098
# 3            0.603081           0.658588           0.705885
# 4            0.565282           0.706839           0.684782
# 5            0.541543           0.697862           0.694321
# 6            0.650712           0.724201           0.741070
# 7            0.609749           0.701312           0.713173
# 8            0.613094           0.753863           0.584890
# 9            0.499696           0.647679           0.662269
# 10           0.592941           0.690550           0.751666
# 11           0.538915           0.662753           0.679901
# 12           0.624202           0.708972           0.726532
# 13           0.607027           0.653457           0.727479
# 14           0.343092           0.697251           0.533984
# 15           0.550568           0.712038           0.690414
# 16           0.613740           0.621626           0.645718
# 17           0.569359           0.538400           0.694110
# 18           0.670981           0.734083           0.720323
# 19           0.614889           0.705317           0.724733
# 20           0.594416           0.514831           0.676046
# 21           0.463474           0.677744           0.673124
# 22           0.627928           0.744822           0.633593
# 23           0.607597           0.654657           0.679319
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.669454         0.699424        0.040286                5
# 1            0.678174         0.666773        0.096311               16
# 2            0.684744         0.701789        0.056119                4
# 3            0.639668         0.662009        0.038921               17
# 4            0.759481         0.697135        0.073111                7
# 5            0.535376         0.632582        0.076888               19
# 6            0.687932         0.705932        0.032663                2
# 7            0.753848         0.697741        0.047555                6
# 8            0.692836         0.679445        0.069862               11
# 9            0.612918         0.614354        0.059615               22
# 10           0.746864         0.679398        0.065612               12
# 11           0.609051         0.632439        0.052910               20
# 12           0.746455         0.704858        0.042187                3
# 13           0.764757         0.688373        0.055137                8
# 14           0.712015         0.574654        0.133659               24
# 15           0.703240         0.676518        0.064052               13
# 16           0.739878         0.671888        0.055945               14
# 17           0.753297         0.661370        0.090848               18
# 18           0.697153         0.713864        0.027027                1
# 19           0.691552         0.688251        0.038178                9
# 20           0.686707         0.626802        0.064559               21
# 21           0.587726         0.610738        0.080336               23
# 22           0.681669         0.681701        0.046250               10
# 23           0.737753         0.667125        0.042316               15

# %%
result= grid.predict([[32,43,2,0,1]])
# Out:
# C:\Anaconda3run\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([40932.4295])

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
grid.best_score_
# Out:
# 0.7138644868071985
