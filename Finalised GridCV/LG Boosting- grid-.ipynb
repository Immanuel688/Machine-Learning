# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
import lightgbm
from lightgbm import LGBMRegressor 
param_grid={'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],}
grid=GridSearchCV(LGBMRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000044 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# GridSearchCV(estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}

# %%
grid.best_score_
# Out:
# 0.8628231946346219

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.287436      0.063727         0.009373        0.007653
# 1        0.234321      0.009882         0.006249        0.007654
# 2        0.340544      0.026876         0.006248        0.007653
# 3        0.159340      0.011692         0.006248        0.007653
# 4        0.296815      0.019750         0.000000        0.000000
# 5        0.524865      0.021195         0.003124        0.006249
# 6        0.149969      0.012494         0.009368        0.007649
# 7        0.290559      0.021190         0.003124        0.006248
# 8        0.559247      0.052648         0.006245        0.007649
# 9        0.078107      0.013971         0.006248        0.007652
# 10       0.149965      0.012498         0.006248        0.007653
# 11       0.278059      0.011690         0.009374        0.007653
# 12       0.140593      0.013974         0.006247        0.007650
# 13       0.218700      0.013975         0.006248        0.007653
# 14       0.393659      0.033360         0.009373        0.007653
# 15       0.137468      0.006249         0.012496        0.006248
# 16       0.271810      0.015931         0.003124        0.006249
# 17       0.490511      0.045916         0.012496        0.006248
# 18       0.078108      0.000006         0.009371        0.007652
# 19       0.153088      0.015303         0.003126        0.006251
# 20       0.278059      0.015306         0.009372        0.007652
# 21       0.118719      0.007652         0.003124        0.006248
# 22       0.203078      0.009880         0.006248        0.007653
# 23       0.393659      0.011683         0.006250        0.007655
# 24       0.137461      0.011693         0.009373        0.007653
# 25       0.256190      0.007653         0.006248        0.007652
# 26       0.440523      0.036167         0.006247        0.007651
#
#    param_learning_rate param_max_depth param_n_estimators  \
# 0                 0.01               3                 50
# 1                 0.01               3                100
# 2                 0.01               3                200
# 3                 0.01               5                 50
# 4                 0.01               5                100
# 5                 0.01               5                200
# 6                 0.01               7                 50
# 7                 0.01               7                100
# 8                 0.01               7                200
# 9                  0.1               3                 50
# 10                 0.1               3                100
# 11                 0.1               3                200
# 12                 0.1               5                 50
# 13                 0.1               5                100
# 14                 0.1               5                200
# 15                 0.1               7                 50
# 16                 0.1               7                100
# 17                 0.1               7                200
# 18                 0.2               3                 50
# 19                 0.2               3                100
# 20                 0.2               3                200
# 21                 0.2               5                 50
# 22                 0.2               5                100
# 23                 0.2               5                200
# 24                 0.2               7                 50
# 25                 0.2               7                100
# 26                 0.2               7                200
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...           0.557956
# 1   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...           0.765052
# 2   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...           0.869871
# 3   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...           0.565401
# 4   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...           0.768386
# 5   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...           0.867886
# 6   {'learning_rate': 0.01, 'max_depth': 7, 'n_est...           0.565129
# 7   {'learning_rate': 0.01, 'max_depth': 7, 'n_est...           0.767262
# 8   {'learning_rate': 0.01, 'max_depth': 7, 'n_est...           0.865692
# 9   {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.885009
# 10  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.881497
# 11  {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.875384
# 12  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...           0.879432
# 13  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...           0.873535
# 14  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...           0.865641
# 15  {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...           0.872454
# 16  {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...           0.865716
# 17  {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...           0.859034
# 18  {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...           0.879834
# 19  {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...           0.874739
# 20  {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...           0.867444
# 21  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...           0.871138
# 22  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...           0.861635
# 23  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...           0.851974
# 24  {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...           0.865874
# 25  {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...           0.858419
# 26  {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...           0.846217
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.522660           0.533052           0.545102
# 1            0.712229           0.740688           0.739026
# 2            0.802934           0.861642           0.835705
# 3            0.529516           0.540273           0.548101
# 4            0.717252           0.750832           0.744604
# 5            0.801622           0.867744           0.836866
# 6            0.529865           0.541177           0.548829
# 7            0.715389           0.751178           0.743623
# 8            0.797393           0.867000           0.833936
# 9            0.815430           0.894452           0.852458
# 10           0.811597           0.893434           0.851057
# 11           0.803791           0.887614           0.849924
# 12           0.805027           0.890906           0.845394
# 13           0.798158           0.885281           0.844743
# 14           0.788939           0.876039           0.837848
# 15           0.797340           0.886863           0.841266
# 16           0.788205           0.879801           0.840428
# 17           0.774749           0.871830           0.830397
# 18           0.810042           0.893360           0.851164
# 19           0.802109           0.886793           0.850442
# 20           0.794144           0.877491           0.843436
# 21           0.800607           0.882525           0.842429
# 22           0.791570           0.873479           0.837176
# 23           0.777293           0.863220           0.828458
# 24           0.785103           0.878710           0.836516
# 25           0.772797           0.868628           0.828089
# 26           0.757154           0.853921           0.822631
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.540986         0.539951        0.011818               27
# 1            0.742400         0.739879        0.016769               24
# 2            0.847661         0.843563        0.023445               13
# 3            0.541983         0.545055        0.011807               25
# 4            0.742790         0.744773        0.016466               22
# 5            0.847173         0.844258        0.024458               12
# 6            0.539830         0.544966        0.011749               26
# 7            0.739423         0.743375        0.016914               23
# 8            0.845271         0.841858        0.025502               17
# 9            0.866767         0.862823        0.027791                1
# 10           0.860707         0.859658        0.028294                2
# 11           0.855275         0.854398        0.028725                5
# 12           0.860792         0.856310        0.030002                4
# 13           0.855125         0.851368        0.030102                8
# 14           0.848433         0.843380        0.030273               15
# 15           0.860529         0.851690        0.031013                7
# 16           0.852010         0.845232        0.031419               11
# 17           0.844499         0.836102        0.033674               18
# 18           0.860489         0.858978        0.028549                3
# 19           0.854193         0.853655        0.029018                6
# 20           0.846759         0.845855        0.028801               10
# 21           0.855684         0.850477        0.028400                9
# 22           0.846477         0.842068        0.028153               16
# 23           0.838123         0.831814        0.029720               20
# 24           0.851420         0.843525        0.032441               14
# 25           0.844034         0.834393        0.033693               19
# 26           0.830415         0.822067        0.034298               21

# %%
result= grid.predict([[32,43,2,0,1]])

# %%
result
# Out:
# array([43521.24399117])

# %%
import pickle
filename="finalized_Model_LGB.sav"
pickle.dump(grid,open("finalized_Model_LGB",'wb'))
