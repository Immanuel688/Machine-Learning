# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset['charges']
dependent
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','linear','sigmoid'], 'C':[10,100,1000,2000,5000], 'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1, cv=3)
grid.fit(independent,dependent)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# GridSearchCV(cv=3, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 5000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'linear', 'sigmoid']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}

# %%
re=grid.cv_results_

# %%
table= pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.083315  7.362773e-03         0.088520    7.362998e-03      10
# 1        0.078105  1.296163e-06         0.015621    5.150430e-07      10
# 2        0.072898  7.363785e-03         0.020828    7.363729e-03      10
# 3        0.088521  7.364347e-03         0.083318    7.368505e-03      10
# 4        0.078098  5.507188e-06         0.020830    7.363673e-03      10
# 5        0.083309  7.366596e-03         0.041659    7.365696e-03      10
# 6        0.083311  7.361144e-03         0.083314    7.363392e-03     100
# 7        0.161419  7.365640e-03         0.026036    7.363729e-03     100
# 8        0.067693  7.363729e-03         0.020828    7.363841e-03     100
# 9        0.067693  7.364347e-03         0.088521    7.363673e-03     100
# 10       0.166628  1.948298e-02         0.020829    7.364122e-03     100
# 11       0.093728  1.275503e-02         0.046864    1.275484e-02     100
# 12       0.140593  1.275513e-02         0.072900    7.364797e-03    1000
# 13       0.572780  5.154854e-02         0.015623    1.123916e-07    1000
# 14       0.062485  6.836514e-07         0.036449    7.363392e-03    1000
# 15       0.083314  7.364684e-03         0.078109    3.371748e-06    1000
# 16       0.555478  8.266048e-02         0.014275    1.903745e-03    1000
# 17       0.088519  7.363111e-03         0.041658    1.472622e-02    1000
# 18       0.157061  4.206059e-03         0.076192    7.410241e-03    2000
# 19       1.366156  4.505040e-01         0.022180    7.898753e-03    2000
# 20       0.069253  2.289387e-03         0.029484    8.591900e-03    2000
# 21       0.110863  7.356370e-03         0.075127    8.203838e-03    2000
# 22       1.346576  4.340417e-01         0.025522    7.380767e-03    2000
# 23       0.104548  8.716955e-03         0.038239    8.806224e-03    2000
# 24       0.275927  1.124737e-02         0.091353    5.844852e-03    5000
# 25       2.251137  2.149440e-01         0.022504    6.511039e-03    5000
# 26       0.068046  9.180812e-04         0.022281    4.805704e-03    5000
# 27       0.096356  4.454350e-03         0.078150    8.860316e-03    5000
# 28       2.038744  2.002961e-01         0.016750    9.925061e-04    5000
# 29       0.096460  1.325067e-02         0.036661    8.004784e-03    5000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto       linear
# 2         auto      sigmoid
# 3        scale          rbf
# 4        scale       linear
# 5        scale      sigmoid
# 6         auto          rbf
# 7         auto       linear
# 8         auto      sigmoid
# 9        scale          rbf
# 10       scale       linear
# 11       scale      sigmoid
# 12        auto          rbf
# 13        auto       linear
# 14        auto      sigmoid
# 15       scale          rbf
# 16       scale       linear
# 17       scale      sigmoid
# 18        auto          rbf
# 19        auto       linear
# 20        auto      sigmoid
# 21       scale          rbf
# 22       scale       linear
# 23       scale      sigmoid
# 24        auto          rbf
# 25        auto       linear
# 26        auto      sigmoid
# 27       scale          rbf
# 28       scale       linear
# 29       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.121859
# 1      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.029744
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.120647
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.029744
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.126045
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113010
# 7     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.535721
# 8    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.147772
# 10   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.535721
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.151746
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.090261
# 13   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.674923
# 14  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.141802
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.674923
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.636325
# 18      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.049231
# 19   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.711945
# 20  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 21     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.131807
# 22  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.711945
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -5.571911
# 24      {'C': 5000, 'gamma': 'auto', 'kernel': 'rbf'}           0.063948
# 25   {'C': 5000, 'gamma': 'auto', 'kernel': 'linear'}           0.667281
# 26  {'C': 5000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.124306
# 27     {'C': 5000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.098239
# 28  {'C': 5000, 'gamma': 'scale', 'kernel': 'linear'}           0.667281
# 29  {'C': 5000, 'gamma': 'scale', 'kernel': 'sigmo...         -32.040584
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           -0.071812          -0.115978        -0.103216        0.022336
# 1            0.024305          -0.087219        -0.030886        0.045536
# 2           -0.073333          -0.116351        -0.104664        0.022391
# 3           -0.062407          -0.126932        -0.103329        0.029050
# 4            0.024305          -0.087219        -0.030886        0.045536
# 5           -0.075274          -0.117573        -0.106297        0.022208
# 6           -0.064058          -0.111684        -0.096251        0.022770
# 7            0.532197           0.486564         0.518161        0.022388
# 8           -0.073333          -0.116351        -0.104664        0.022391
# 9           -0.094747          -0.201098        -0.147873        0.043418
# 10           0.532197           0.486564         0.518161        0.022388
# 11          -0.103873          -0.138200        -0.131273        0.020148
# 12          -0.036964          -0.131036        -0.086087        0.038518
# 13           0.673021           0.642308         0.663417        0.014947
# 14          -0.073333          -0.116351        -0.104664        0.022391
# 15          -0.098386          -0.202734        -0.147641        0.042799
# 16           0.673021           0.642308         0.663417        0.014947
# 17          -1.642364          -1.478968        -1.585886        0.075642
# 18          -0.004898          -0.091546        -0.048558        0.035377
# 19           0.735741           0.658711         0.702132        0.032204
# 20          -0.073333          -0.116351        -0.104664        0.022391
# 21          -0.091517          -0.195013        -0.139446        0.042596
# 22           0.735741           0.658711         0.702132        0.032204
# 23          -5.741249          -5.162330        -5.491830        0.243032
# 24           0.102473           0.037181         0.067867        0.026799
# 25           0.713264           0.639539         0.673361        0.030404
# 26          -0.073333          -0.116351        -0.104664        0.022391
# 27          -0.058314          -0.162016        -0.106190        0.042708
# 28           0.713264           0.639539         0.673361        0.030404
# 29         -33.694801         -29.671690       -31.802358        1.651044
#
#     rank_test_score
# 0                15
# 1                10
# 2                17
# 3                16
# 4                10
# 5                23
# 6                14
# 7                 7
# 8                17
# 9                27
# 10                7
# 11               24
# 12               13
# 13                5
# 14               17
# 15               26
# 16                5
# 17               28
# 18               12
# 19                1
# 20               17
# 21               25
# 22                1
# 23               29
# 24                9
# 25                3
# 26               17
# 27               22
# 28                3
# 29               30

# %%
grid.best_score_
# Out:
# 0.7021323301015325
